# %%
# !sudo apt install cmake
# !pip install dlib==19.18
# !pip install face_recognition
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# ...

# %%
import cv2
import numpy as np
import face_recognition

# %%
dir(face_recognition.load_image_file)
# Out:
# ['__annotations__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
# %matplotlib inline
#The line above is necesary to show Matplotlib's plots inside a Jupyter Notebook

import cv2
from matplotlib import pyplot as plt

#Import image
ImgParag = cv2.imread("/content/My_image/IMG_20200508_122619_163.jpg")

#Show the image with matplotlib
plt.imshow(ImgParag)
plt.show()

#Import image
ImgParagTest = cv2.imread("/content/My_image/IMG_20200508_144028_710.jpg")

#Show the image with matplotlib
plt.imshow(ImgParagTest)
plt.show()

# %%
ImgParag = face_recognition.load_image_file('/content/My_image/IMG_20200508_122619_163.jpg')
ImgParagTest = face_recognition.load_image_file('/content/My_image/IMG_20200508_144028_710.jpg')

# %%
face_locations = face_recognition.face_locations(ImgParag)

# %%
from PIL import Image, ImageDraw
from IPython.display import display

# The program we will be finding faces on the example below
pil_im = Image.open('/content/new_image/parag.jpg')
display(pil_im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x7F7E96805A90>

# %% [markdown]
# # Learning from example
# Now we show the library two different faces (Joe Biden, Barack Obama) and generate the encodings for them. Encoding is simply a low dimensional representation of a face that can be easily compared with other faces the library will recognize in the future.

# %%
import face_recognition
import numpy as np
from PIL import Image, ImageDraw
from IPython.display import display

# This is an example of running face recognition on a single image
# and drawing a box around each person that was identified.

# Load a sample picture and learn how to recognize it.
parag_image = face_recognition.load_image_file("/content/My_image/parag.jpg")
parag_face_encoding = face_recognition.face_encodings(parag_image)[0]

# Load a second sample picture and learn how to recognize it.
vivek_image = face_recognition.load_image_file("/content/My_image/vivek.jpeg")
vivek_face_encoding = face_recognition.face_encodings(vivek_image)

# Create arrays of known face encodings and their names
known_face_encodings = [
    parag_face_encoding,
    raushan_face_encoding
]
known_face_names = [
    "Parag",
    "Vivek"
]

print('Learned encoding for', len(known_face_encodings), 'images.')
# Out:
# Learned encoding for 2 images.

# %%
print(parag_face_encoding)
# Out:
# [-1.01628944e-01  5.29560968e-02  2.73960494e-02 -7.03428909e-02
#  -6.85628355e-02 -2.20245123e-02  1.07615441e-03 -8.38655680e-02
#   1.88767403e-01 -1.69405937e-01  1.88415915e-01 -5.72717190e-03
#  -2.08769768e-01 -1.08130306e-01 -4.21062112e-04  7.19705969e-02
#  -1.47111297e-01 -2.12103486e-01 -3.01756784e-02 -3.43752205e-02
#   2.76264250e-02 -1.22010149e-02  6.16155937e-02  4.17655557e-02
#  -1.44771546e-01 -3.95854950e-01 -9.91137326e-02 -1.53559968e-01
#   7.55769461e-02 -1.48842126e-01 -2.03053653e-03  1.37248337e-02
#  -2.09061712e-01  2.95919925e-03 -4.86994758e-02  7.67678916e-02
#   5.77919260e-02 -4.15349379e-02  2.49214828e-01  3.74959409e-03
#  -2.29873762e-01 -8.09948817e-02  3.68828513e-02  2.21950814e-01
#   1.03034630e-01  5.14516085e-02  3.01117860e-02 -7.64905959e-02
#   1.71750456e-01 -1.68559447e-01  1.46853507e-01  6.76800609e-02
#   1.66838318e-01 -3.88676599e-02  1.00372016e-01 -1.52655184e-01
# ...

# %%
print(vivek_face_encoding)
# Out:
# [array([-1.34140685e-01,  7.63994381e-02,  1.78525038e-02, -8.01067203e-02,
#        -5.83056174e-02, -6.66904449e-03, -6.76590577e-02, -6.82937726e-02,
#         1.96276426e-01, -1.08723775e-01,  2.09523559e-01, -1.45990327e-02,
#        -1.70303732e-01, -9.59810913e-02, -6.12890571e-02,  8.80378485e-02,
#        -2.48732671e-01, -1.90179482e-01,  2.05890536e-02, -7.13960826e-02,
#         7.56967664e-02, -8.74407589e-02, -1.47898197e-02,  8.40441287e-02,
#        -1.91618040e-01, -3.59220147e-01, -7.65893310e-02, -1.11328125e-01,
#         4.79357354e-02, -1.23347819e-01, -1.07914507e-02,  3.84490229e-02,
#        -2.24079922e-01, -5.68362325e-03, -7.63937160e-02,  1.00906223e-01,
#         3.35451737e-02,  3.05227190e-03,  1.41243160e-01,  2.95351893e-02,
#        -1.43641204e-01,  1.44673660e-02, -1.02431849e-02,  2.86040962e-01,
#         2.29471192e-01,  6.67136908e-02, -9.42498446e-06, -2.06594169e-03,
# ...

# %% [markdown]
# # Showtime
# Finally, we load the image we looked at in the first cell, find the faces in the image and compare them with the encodings the library generated in the previous step. We can see that library now correctly recognizes Barack and Joe in the input.

# %%
# Load an image with an unknown face
unknown_image = face_recognition.load_image_file("/content/new_image/Unknown.jpg")

# Find all the faces and face encodings in the unknown image
face_locations = face_recognition.face_locations(unknown_image)
face_encodings = face_recognition.face_encodings(unknown_image, face_locations)

# Convert the image to a PIL-format image so that we can draw on top of it with the Pillow library
# See http://pillow.readthedocs.io/ for more about PIL/Pillow
pil_image = Image.fromarray(unknown_image)
# Create a Pillow ImageDraw Draw instance to draw with
draw = ImageDraw.Draw(pil_image)

# Loop through each face found in the unknown image
for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
    # See if the face is a match for the known face(s)
    matches = face_recognition.compare_faces(known_face_encodings, face_encoding)

    name = "Unknown"

    # Or instead, use the known face with the smallest distance to the new face
    face_distances = face_recognition.face_distance(known_face_encodings, face_encoding)
    best_match_index = np.argmin(face_distances)
    if matches[best_match_index]:
        name = known_face_names[best_match_index]

    # Draw a box around the face using the Pillow module
    draw.rectangle(((left, top), (right, bottom)), outline=(0, 0, 255))

    # Draw a label with a name below the face
    text_width, text_height = draw.textsize(name)
    draw.rectangle(((left, bottom - text_height - 10), (right, bottom)), fill=(0, 0, 255), outline=(0, 0, 255))
    draw.text((left + 6, bottom - text_height - 5), name, fill=(255, 255, 255, 255))


# Remove the drawing library from memory as per the Pillow docs
del draw

# Display the resulting image
display(pil_image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x640 at 0x7F7E98051A20>

# %%
# /content/new_image

#Import image
ImgVivek = cv2.imread("/content/My_image/vivek.jpeg")

#Show the image with matplotlib
plt.imshow(ImgVivek)
plt.show()

print(ImgVivek.shape)
# ImgParag_new = cv2.resize()
#Save the image
cv2.imwrite('/content/new_image/vivek.jpg',ImgVivek)


ImgParag = cv2.imread("/content/My_image/parag.jpg")
print(ImgParag.shape)
ImgParag = cv2.resize(ImgParag,(640,640),3)
print(ImgParag.shape)

#Show the image with matplotlib
plt.imshow(ImgParag)
plt.show()

#Save the image
cv2.imwrite('/content/new_image/parag.jpg',ImgParag)


Imgtest = cv2.imread("/content/My_image/test.jpg")
print(Imgtest.shape)
Imgtest = cv2.resize(Imgtest,(640,640),3)
print(Imgtest.shape)

#Show the image with matplotlib
plt.imshow(Imgtest)
plt.show()

#Save the image
cv2.imwrite('/content/new_image/test.jpg',Imgtest)
# Out:
# (640, 640, 3)
# (1358, 720, 3)
# (640, 640, 3)
# (1358, 720, 3)
# (640, 640, 3)
# True

# %%
picture_of_me = face_recognition.load_image_file("/content/My_image/parag.jpg")
my_face_encoding = face_recognition.face_encodings(picture_of_me)[0]


picture_of_vivek = face_recognition.load_image_file("/content/My_image/parag.jpg")
vivek_face_encoding = face_recognition.face_encodings(picture_of_vivek)[0]


# my_face_encoding now contains a universal 'encoding' of my facial features that can be compared to any other picture of a face!

unknown_picture = face_recognition.load_image_file("/content/My_image/test.jpg")
unknown_face_encoding = face_recognition.face_encodings(unknown_picture)[0]

# Now we can see the two face encodings are of the same person with `compare_faces`!

# results = face_recognition.compare_faces([my_face_encoding], unknown_face_encoding)
for person in 


if results[0] == True:
    print("It's a picture of me!")
else:
    print("It's not a picture of me!")
# Out:
# It's a picture of me!

# %%
import os

list_images = os.listdir("/content/images/")
print(list_images)
list_images = [x for x in list_images if x.endswith('.jpg') or x.endswith('.jpeg')]
print(list_images)

names = []

for x in list_images:
  names.append(x.split(".")[0])
print(names)
# Out:
# ['vivek.jpeg', 'test.jpg', 'parag.jpg', '.ipynb_checkpoints']
# ['vivek.jpeg', 'test.jpg', 'parag.jpg']
# ['vivek', 'test', 'parag']

# %%
path_img = '/content/My_image/'

for name in range(len(names)):
  name_img = names[name]
  name_img = face_recognition.load_image_file(path_img+list_images[name])
  my_face_encoding = face_recognition.face_encodings(picture_of_me)[0]
